# %% [markdown]
# <a href="https://colab.research.google.com/github/Je-97/Analysis-Dataset/blob/main/Personal-Finance-Manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt

# %%
class Transaction:
    def __init__(self, type, amount, category, date, account):
        self.type = type
        self.amount = amount
        self.category = category
        self.date = date
        self.account = account

transactions = []
categories = ["Salary", "Rent", "Groceries", "Utilities"]
account_types = ["Checking", "Savings", "Credit Card"]

while True:
    type = input("Please enter the transaction type (Income/Expense): ")
    amount = float(input("Please enter the amount: "))

    print("Please select a category or add a new one:")
    for i, category in enumerate(categories):
        print(f"{i+1}. {category}")
    category_choice = int(input("Selection: "))
    category = categories[category_choice-1]

    date = input("Please enter the date (YYYY-MM-DD): ")

    print("Please enter the account type:")
    for i, account_type in enumerate(account_types):
        print(f"{i+1}. {account_type}")
    account_choice = int(input("Selection: "))
    account = account_types[account_choice-1]

    transaction = Transaction(type, amount, category, date, account)
    transactions.append(transaction)

    continue_prompt = input("Do you want to continue? (yes/no): ")
    if continue_prompt.lower() != "yes":
        break

for transaction in transactions:
    print(f"Type: {transaction.type}, Amount: {transaction.amount}, Category: {transaction.category}, Date: {transaction.date}, Account: {transaction.account}")
# Out:
# Please enter the transaction type (Income/Expense): Income
# Please enter the amount: 9000
# Please select a category or add a new one:
# 1. Salary
# 2. Rent
# 3. Groceries
# 4. Utilities
# Selection: 1
# Please enter the date (YYYY-MM-DD): 2023-10-10\
# Please enter the account type:
# 1. Checking
# 2. Savings
# 3. Credit Card
# Selection: 3
# Do you want to continue? (yes/no): no
# Type: Income, Amount: 9000.0, Category: Salary, Date: 2023-10-10\, Account: Credit Card

# %%
class PersonalFinanceManager:
    def __init__(self):
        self.accounts = {}

    def add_account(self, name, balance=0):
        self.accounts[name] = balance

    def add_transaction(self, account, date, type, category, description, amount):
        if account not in self.accounts:
            self.add_account(account)
        if type == "Expense":
            self.accounts[account] -= amount
        else:
            self.accounts[account] += amount

    def import_transactions(self, file_path):
        with open('transactions.csv', 'r') as file:
            reader = csv.reader(file)
            next(reader)
            for row in reader:
                date, type, category, description, amount_str, account = row
                try:
                    amount = float(amount_str)
                except ValueError:
                    continue
                self.add_transaction(account, date, type, category, description, amount)

    def view_all_accounts_balance_summary(self):
        for account, balance in self.accounts.items():
            print(f"{account}: {balance}")


pf_manager = PersonalFinanceManager()


pf_manager.import_transactions('transactions.csv')


while True:
    print("\nMain Menu:")
    print("1. Add a transaction")
    print("2. Import Transaction Data File")
    print("3. View All Accounts Balance Summary")
    print("4. Back to Main Menu")
    option = input("Select an option: ")
    if option == "1":
        account = input("Enter the account name: ")
        date = input("Enter the date (YYYY-MM-DD): ")
        type = input("Enter the type of transaction (Income or Expense): ")
        category = input("Enter the category: ")
        description = input("Enter the description: ")
        amount = float(input("Enter the amount: "))
        pf_manager.add_transaction(account, date, type, category, description, amount)
        print("Transaction added successfully.")
    elif option == "2":
        file_path = input("Enter the file path: ")
        pf_manager.import_transactions(file_path)
        print("All transactions imported and added to the accounts successfully.")
    elif option == "3":
        pf_manager.view_all_accounts_balance_summary()
    elif option == "4":
        break
# Out:
# Main Menu:
# 1. Add a transaction
# 2. Import Transaction Data File
# 3. View All Accounts Balance Summary
# 4. Back to Main Menu
# Select an option: 1
# Enter the account name: Checking
# Enter the date (YYYY-MM-DD): 2023-10-10
# Enter the type of transaction (Income or Expense): Income
# Enter the category: for saving
# Enter the description: for svaing
# Enter the amount: 500
# Transaction added successfully.
#
# Main Menu:
# 1. Add a transaction
# 2. Import Transaction Data File
# 3. View All Accounts Balance Summary
# 4. Back to Main Menu
# Select an option: 4

# %%
def read_transactions(file_name):
    with open(file_name, 'r') as file:
        reader = csv.DictReader(file)
        transactions = list(reader)
    return transactions

def filter_by_date(transactions, start_date, end_date):
    start_date = datetime.strptime(start_date, '%d/%m/%Y')
    end_date = datetime.strptime(end_date, '%d/%m/%Y')

    filtered_transactions = []
    for transaction in transactions:
        try:
            transaction_date = datetime.strptime(transaction['Date/time'], '%d-%m-%Y')
        except ValueError:
            transaction_date = datetime.strptime(transaction['Date/time'], '%d/%m/%Y')
        if start_date <= transaction_date <= end_date:
            filtered_transactions.append(transaction)

    return filtered_transactions

def get_income_by_category(transactions):
    income_by_category = {}
    for transaction in transactions:
        if transaction['Type of Transfer'] == 'Income':
            category = transaction['Category']
            amount = float(transaction['Amount'].replace('$', ''))
            income_by_category[category] = income_by_category.get(category, 0) + amount
    return income_by_category

def visualize_income_distribution_by_category(income_by_category):
    categories = list(income_by_category.keys())
    amounts = list(income_by_category.values())

    plt.pie(amounts, labels=categories, autopct='%1.1f%%')
    plt.axis('equal')
    plt.title('Income Distribution by Category')
    plt.show()

# Example usage
start_date = '01/01/2021'
end_date = '31/12/2023'
file_name = r'transactions.csv'

transactions = read_transactions(file_name)
filtered_transactions = filter_by_date(transactions, start_date, end_date)
income_by_category = get_income_by_category(filtered_transactions)
visualize_income_distribution_by_category(income_by_category)

# %%
def plot_account_balances(file_path):
    data = pd.read_csv(file_path)

    account_types = data['Account Type']
    balances = data['Amount'].str.replace('$', '').astype(float)

    plt.bar(account_types, balances)
    plt.title('Account Balances')
    plt.xlabel('Account Type')
    plt.ylabel('Balance')
    plt.xticks(rotation=90)
    plt.show()
plot_account_balances('transactions.csv')

# %%
class PersonalFinanceManager:
    def __init__(self):
        self.accounts = {}

    def add_account(self, account_name):
        if account_name not in self.accounts:
            self.accounts[account_name] = {"balance": 0, "transactions": []}

    def add_transaction(self, account_name, transaction):
        self.add_account(account_name)
        self.accounts[account_name]["transactions"].append(transaction)
        if transaction["Type of Transfer"] == "Expense":
            self.accounts[account_name]["balance"] -= transaction["Amount"]
        else:
            self.accounts[account_name]["balance"] += transaction["Amount"]

    def get_balance(self, account_name):
        return self.accounts[account_name]["balance"]

    def filter_by_date(self, account_name, start_date, end_date):
     start_date = datetime.strptime(start_date, "%Y-%m-%d")
     end_date = datetime.strptime(end_date, "%Y-%m-%d")
     return [t for t in self.accounts[account_name]["transactions"] if start_date <= datetime.strptime(t["date"], "%Y-%m-%d") <= end_date]


    def filter_by_category(self, account_name, category):
        return [t for t in self.accounts[account_name]["transactions"] if t["category"] == category]

    def filter_by_account_type(self):
        account_type = input("Enter the account type: ")
        for account_name, account_info in self.accounts.items():
            if account_info["type"] == account_type:
                print(f"Account Name: {account_name}")
                for transaction in account_info["transactions"]:
                    print(transaction)


pf_manager = PersonalFinanceManager()

with open('transactions.csv', 'r') as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        date_time, type_of_transfer, category, details, amount, account_type = row
        transaction = {"date": date_time, "Type of Transfer": type_of_transfer, "category": category, "details": details, "Amount": float(amount.replace('$', ''))}
        pf_manager.add_transaction(account_type, transaction)

while True:
    print("\nMain Menu:")
    print("1. Filter by Category")
    print("2. Filter by Date")
    print("3. Filter by Account Type")
    print("0. Back to Main Menu")
    option = input("Select an option: ")
    if option == "1":
        account_name = input("Enter the account name: ")
        category = input("Enter the desired category: ")
        transactions = pf_manager.filter_by_category(account_name, category)
        print("Filtered transactions:")
        for transaction in transactions:
            print(transaction)
    elif option == "2":
        account_name = input("Enter the account name: ")
        start_date = input("Enter the start date (YYYY-MM-DD): ")
        end_date = input("Enter the end date (YYYY-MM-DD): ")
        transactions = pf_manager.filter_by_date(account_name, start_date, end_date)
        print("Filtered transactions:")
        for transaction in transactions:
            print(transaction)
    elif option == "3":
        pf_manager.filter_by_account_type()
    elif option == "0":
        break
# Out:
# Main Menu:
# 1. Filter by Category
# 2. Filter by Date
# 3. Filter by Account Type
# 0. Back to Main Menu
# Filtered transactions:
# {'date': '8/1/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 441.31}
# {'date': '9/1/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 579.72}
# {'date': '12/1/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 502.58}
# {'date': '13-01-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 514.35}
# {'date': '16-01-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 488.63}
# {'date': '20-01-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 518.5}
# {'date': '26-01-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 552.87}
# {'date': '27-01-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 572.63}
# {'date': '29-01-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 494.68}
# {'date': '5/2/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 483.67}
# {'date': '9/2/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 493.81}
# {'date': '12/2/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 431.41}
# {'date': '13-02-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 444.64}
# {'date': '14-02-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 489.22}
# {'date': '15-02-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 507.89}
# {'date': '16-02-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 490.19}
# {'date': '20-02-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 527.42}
# {'date': '22-02-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 433.36}
# {'date': '27-02-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 395.9}
# {'date': '4/3/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 508.29}
# {'date': '6/3/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 540.73}
# {'date': '10/3/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 424.64}
# {'date': '12/3/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 484.11}
# {'date': '13-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 484.19}
# {'date': '15-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 525.12}
# {'date': '18-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 550.19}
# {'date': '21-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 521.69}
# {'date': '22-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 442.8}
# {'date': '24-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 427.38}
# {'date': '25-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 430.3}
# {'date': '27-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 506.77}
# {'date': '28-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 640.3}
# {'date': '29-03-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 599.79}
# {'date': '1/4/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 576.09}
# {'date': '16-04-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 408.54}
# {'date': '19-04-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 485.03}
# {'date': '22-04-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 592.4}
# {'date': '23-04-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 540.0}
# {'date': '26-04-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 521.35}
# {'date': '28-04-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 496.07}
# {'date': '29-04-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 491.53}
# {'date': '30-04-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 555.68}
# {'date': '10/5/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 372.0}
# {'date': '12/5/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 557.73}
# {'date': '17-05-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 449.13}
# {'date': '20-05-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 526.02}
# {'date': '22-05-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 467.98}
# {'date': '23-05-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 540.49}
# {'date': '27-05-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 538.87}
# {'date': '2/6/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 473.53}
# {'date': '3/6/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 547.44}
# {'date': '5/6/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 449.28}
# {'date': '6/6/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 568.7}
# {'date': '12/6/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 430.0}
# {'date': '17-06-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 619.61}
# {'date': '19-06-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 524.39}
# {'date': '20-06-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 474.41}
# {'date': '22-06-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 526.92}
# {'date': '26-06-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 514.46}
# {'date': '27-06-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 551.86}
# {'date': '1/7/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 626.97}
# {'date': '2/7/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 478.19}
# {'date': '5/7/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 489.43}
# {'date': '8/7/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 450.24}
# {'date': '15-07-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 457.88}
# {'date': '18-07-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 472.6}
# {'date': '25-07-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 559.67}
# {'date': '27-07-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 518.77}
# {'date': '4/8/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 543.81}
# {'date': '5/8/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 495.45}
# {'date': '7/8/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 472.95}
# {'date': '9/8/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 462.6}
# {'date': '10/8/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 474.99}
# {'date': '11/8/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 501.84}
# {'date': '17-08-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 482.32}
# {'date': '19-08-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 427.45}
# {'date': '24-08-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 522.95}
# {'date': '26-08-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 504.66}
# {'date': '27-08-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 523.83}
# {'date': '29-08-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 472.02}
# {'date': '30-08-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 504.15}
# {'date': '31-08-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 453.88}
# {'date': '3/9/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 516.17}
# {'date': '16-09-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 511.45}
# {'date': '25-09-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 598.1}
# {'date': '27-09-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 582.32}
# {'date': '30-09-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 533.75}
# {'date': '5/10/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 411.93}
# {'date': '6/10/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 610.22}
# {'date': '8/10/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 491.88}
# {'date': '12/10/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 567.91}
# {'date': '15-10-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 498.89}
# {'date': '16-10-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 595.17}
# {'date': '17-10-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 522.88}
# {'date': '18-10-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 529.59}
# {'date': '19-10-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 580.8}
# {'date': '23-10-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 560.87}
# {'date': '29-10-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 467.4}
# {'date': '31-10-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 523.31}
# {'date': '3/11/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 550.33}
# {'date': '5/11/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 524.7}
# {'date': '7/11/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 534.94}
# {'date': '8/11/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 443.3}
# {'date': '11/11/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 429.36}
# {'date': '12/11/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 504.2}
# {'date': '16-11-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 563.72}
# {'date': '21-11-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 488.55}
# {'date': '22-11-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 476.67}
# {'date': '27-11-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 454.48}
# {'date': '28-11-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 624.92}
# {'date': '3/12/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 523.0}
# {'date': '7/12/2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 490.33}
# {'date': '14-12-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 461.88}
# {'date': '15-12-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 466.53}
# {'date': '18-12-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 535.13}
# {'date': '26-12-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 516.6}
# {'date': '30-12-2021', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 541.1}
# {'date': '1/1/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 598.46}
# {'date': '2/1/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 518.36}
# {'date': '11/1/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 548.62}
# {'date': '13-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 595.31}
# {'date': '15-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 465.62}
# {'date': '19-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 553.22}
# {'date': '20-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 586.11}
# {'date': '24-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 526.69}
# {'date': '25-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 439.66}
# {'date': '26-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 497.08}
# {'date': '28-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 545.95}
# {'date': '29-01-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 556.37}
# {'date': '6/2/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 492.91}
# {'date': '17-02-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 501.71}
# {'date': '23-02-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 469.41}
# {'date': '1/3/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 598.88}
# {'date': '13-03-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 531.01}
# {'date': '21-03-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 549.05}
# {'date': '26-03-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 505.89}
# {'date': '27-03-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 545.63}
# {'date': '29-03-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 529.66}
# {'date': '3/4/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 559.08}
# {'date': '6/4/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 518.34}
# {'date': '8/4/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 502.87}
# {'date': '9/4/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 616.21}
# {'date': '12/4/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 567.42}
# {'date': '14-04-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 456.21}
# {'date': '15-04-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 495.08}
# {'date': '18-04-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 646.23}
# {'date': '19-04-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 501.84}
# {'date': '1/5/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 559.08}
# {'date': '4/5/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 474.64}
# {'date': '9/5/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 505.21}
# {'date': '19-05-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 597.89}
# {'date': '20-05-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 615.34}
# {'date': '22-05-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 542.44}
# {'date': '31-05-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 555.64}
# {'date': '4/6/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 566.39}
# {'date': '12/6/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 625.36}
# {'date': '14-06-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 512.22}
# {'date': '17-06-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 478.25}
# {'date': '19-06-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 514.19}
# {'date': '4/7/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 535.6}
# {'date': '6/7/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 453.49}
# {'date': '12/7/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 532.13}
# {'date': '14-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 555.54}
# {'date': '15-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 608.19}
# {'date': '16-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 489.07}
# {'date': '17-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 465.38}
# {'date': '18-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 421.56}
# {'date': '21-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 587.66}
# {'date': '25-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 559.84}
# {'date': '26-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 554.75}
# {'date': '28-07-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 491.56}
# {'date': '1/8/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 607.35}
# {'date': '2/8/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 575.19}
# {'date': '6/8/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 529.27}
# {'date': '8/8/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 454.14}
# {'date': '9/8/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 486.07}
# {'date': '14-08-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 632.4}
# {'date': '17-08-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 518.5}
# {'date': '19-08-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 621.7}
# {'date': '22-08-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 603.38}
# {'date': '24-08-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 501.64}
# {'date': '25-08-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 608.39}
# {'date': '26-08-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 576.45}
# {'date': '28-08-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 581.26}
# {'date': '4/9/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 559.82}
# {'date': '12/9/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 570.12}
# {'date': '19-09-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 516.68}
# {'date': '20-09-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 459.13}
# {'date': '22-09-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 525.04}
# {'date': '25-09-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 534.32}
# {'date': '27-09-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 512.11}
# {'date': '3/10/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 560.52}
# {'date': '6/10/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 492.41}
# {'date': '10/10/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 501.23}
# {'date': '11/10/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 537.47}
# {'date': '12/10/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 517.49}
# {'date': '13-10-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 472.98}
# {'date': '17-10-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 546.05}
# {'date': '20-10-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 643.04}
# {'date': '23-10-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 575.6}
# {'date': '25-10-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 544.32}
# {'date': '29-10-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 566.1}
# {'date': '31-10-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 530.32}
# {'date': '2/11/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 571.82}
# {'date': '7/11/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 545.39}
# {'date': '17-11-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 542.08}
# {'date': '25-11-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 580.37}
# {'date': '26-11-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 512.47}
# {'date': '27-11-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 491.3}
# {'date': '3/12/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 646.94}
# {'date': '6/12/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 570.06}
# {'date': '7/12/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 431.44}
# {'date': '8/12/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 474.56}
# {'date': '11/12/2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 432.6}
# {'date': '16-12-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 511.6}
# {'date': '17-12-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 508.57}
# {'date': '20-12-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 522.25}
# {'date': '21-12-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 549.11}
# {'date': '25-12-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 622.87}
# {'date': '28-12-2022', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 564.53}
# {'date': '1/1/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 562.32}
# {'date': '2/1/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 666.42}
# {'date': '4/1/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 615.81}
# {'date': '6/1/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 600.86}
# {'date': '8/1/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 514.46}
# {'date': '17-01-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 582.95}
# {'date': '19-01-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 488.0}
# {'date': '20-01-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 538.15}
# {'date': '21-01-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 556.74}
# {'date': '23-01-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 581.64}
# {'date': '25-01-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 616.92}
# {'date': '27-01-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 560.65}
# {'date': '1/2/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 615.25}
# {'date': '2/2/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 503.49}
# {'date': '8/2/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 666.45}
# {'date': '10/2/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 485.54}
# {'date': '12/2/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 535.37}
# {'date': '14-02-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 523.64}
# {'date': '19-02-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 446.07}
# {'date': '20-02-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 510.73}
# {'date': '22-02-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 562.45}
# {'date': '24-02-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 549.58}
# {'date': '4/3/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 519.73}
# {'date': '17-03-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 500.29}
# {'date': '23-03-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 576.46}
# {'date': '25-03-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 583.43}
# {'date': '26-03-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 615.61}
# {'date': '27-03-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 706.46}
# {'date': '30-03-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 543.54}
# {'date': '6/4/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 534.61}
# {'date': '9/4/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 601.1}
# {'date': '10/4/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 667.73}
# {'date': '14-04-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 633.54}
# {'date': '15-04-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 633.87}
# {'date': '17-04-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 629.38}
# {'date': '20-04-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 606.97}
# {'date': '23-04-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 575.06}
# {'date': '29-04-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 616.73}
# {'date': '3/5/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 630.97}
# {'date': '4/5/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 551.69}
# {'date': '8/5/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 521.23}
# {'date': '12/5/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 649.9}
# {'date': '16-05-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 515.11}
# {'date': '18-05-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 612.72}
# {'date': '20-05-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 536.29}
# {'date': '23-05-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 570.31}
# {'date': '25-05-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 513.9}
# {'date': '26-05-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 652.45}
# {'date': '29-05-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 409.52}
# {'date': '1/6/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 545.04}
# {'date': '7/6/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 490.72}
# {'date': '8/6/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 499.55}
# {'date': '11/6/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 583.47}
# {'date': '16-06-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 554.29}
# {'date': '23-06-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 458.94}
# {'date': '24-06-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 563.33}
# {'date': '27-06-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 562.74}
# {'date': '30-06-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 636.23}
# {'date': '4/7/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 477.95}
# {'date': '5/7/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 606.54}
# {'date': '10/7/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 496.26}
# {'date': '12/7/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 516.36}
# {'date': '13-07-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 599.88}
# {'date': '14-07-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 641.24}
# {'date': '17-07-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 495.55}
# {'date': '19-07-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 472.41}
# {'date': '20-07-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 598.91}
# {'date': '22-07-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 547.71}
# {'date': '26-07-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 594.54}
# {'date': '1/8/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 516.9}
# {'date': '4/8/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 516.57}
# {'date': '6/8/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 588.55}
# {'date': '8/8/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 586.43}
# {'date': '9/8/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 520.15}
# {'date': '10/8/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 473.31}
# {'date': '13-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 490.19}
# {'date': '14-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 556.99}
# {'date': '15-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 510.23}
# {'date': '16-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 528.4}
# {'date': '17-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 535.36}
# {'date': '18-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 614.7}
# {'date': '22-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 638.11}
# {'date': '23-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 572.27}
# {'date': '25-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 527.26}
# {'date': '26-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 546.06}
# {'date': '27-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 575.95}
# {'date': '28-08-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 547.52}
# {'date': '5/9/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 567.67}
# {'date': '6/9/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 542.42}
# {'date': '7/9/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 563.16}
# {'date': '11/9/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 621.82}
# {'date': '12/9/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 474.81}
# {'date': '20-09-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 485.63}
# {'date': '21-09-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 577.05}
# {'date': '25-09-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 621.02}
# {'date': '26-09-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 623.42}
# {'date': '27-09-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 605.74}
# {'date': '29-09-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 571.57}
# {'date': '30-09-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 565.89}
# {'date': '1/10/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 498.6}
# {'date': '10/10/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 695.33}
# {'date': '11/10/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 561.26}
# {'date': '14-10-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 584.16}
# {'date': '20-10-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 605.31}
# {'date': '22-10-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 579.61}
# {'date': '23-10-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 472.88}
# {'date': '24-10-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 493.5}
# {'date': '25-10-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 584.07}
# {'date': '27-10-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 578.17}
# {'date': '31-10-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 599.05}
# {'date': '1/11/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 477.13}
# {'date': '2/11/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 595.77}
# {'date': '5/11/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 562.73}
# {'date': '6/11/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 546.06}
# {'date': '8/11/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 579.01}
# {'date': '10/11/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 605.71}
# {'date': '11/11/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 518.51}
# {'date': '12/11/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 623.62}
# {'date': '18-11-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 512.64}
# {'date': '19-11-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 595.02}
# {'date': '25-11-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 529.84}
# {'date': '29-11-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 582.39}
# {'date': '5/12/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 526.78}
# {'date': '9/12/2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 600.42}
# {'date': '14-12-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 523.14}
# {'date': '20-12-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 515.33}
# {'date': '25-12-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 572.33}
# {'date': '28-12-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 561.18}
# {'date': '30-12-2023', 'Type of Transfer': 'Income', 'category': 'freelancing', 'details': 'Project', 'Amount': 561.06}
#
# Main Menu:
# 1. Filter by Category
# 2. Filter by Date
# 3. Filter by Account Type
# 0. Back to Main Menu
